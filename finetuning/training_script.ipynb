# %% [markdown]
# # Finetuning GPT2 distilled model with Huggingface on Colab

# %% [markdown]
# ### Clone transformers repo and initialize

# %%
# !git clone https://github.com/huggingface/transformers;
# !cd transformers; pip3 install .
# Out:
# Cloning into 'transformers'...
# remote: Enumerating objects: 135154, done.
# remote: Counting objects: 100% (242/242), done.
# remote: Compressing objects: 100% (173/173), done.
# remote: Total 135154 (delta 106), reused 163 (delta 55), pack-reused 134912
# Receiving objects: 100% (135154/135154), 132.61 MiB | 37.45 MiB/s, done.
# Resolving deltas: 100% (101738/101738), done.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing /content/transformers
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 KB 5.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 77.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Finetuning

# %%
# securely copy data for training from gdrive
# !scp /content/drive/MyDrive/ml/recipes/data_train.txt data_train.txt

# %%
# run script which handles fine tuning
# !bash finetuning.sh
# Out:
# Streaming output truncated to the last 5000 lines.
# Iteration:  48% 4330/9044 [16:12<14:49,  5.30it/s]
# Iteration:  48% 4331/9044 [16:12<14:47,  5.31it/s]
# Iteration:  48% 4332/9044 [16:13<14:46,  5.32it/s]
# Iteration:  48% 4333/9044 [16:13<14:45,  5.32it/s]
# Iteration:  48% 4334/9044 [16:13<14:44,  5.32it/s]
# Iteration:  48% 4335/9044 [16:13<14:43,  5.33it/s]
# Iteration:  48% 4336/9044 [16:13<14:44,  5.33it/s]
# Iteration:  48% 4337/9044 [16:13<14:44,  5.32it/s]
# Iteration:  48% 4338/9044 [16:14<14:45,  5.32it/s]
# Iteration:  48% 4339/9044 [16:14<14:44,  5.32it/s]
# Iteration:  48% 4340/9044 [16:14<14:43,  5.32it/s]
# Iteration:  48% 4341/9044 [16:14<14:43,  5.32it/s]
# Iteration:  48% 4342/9044 [16:14<14:43,  5.32it/s]
# Iteration:  48% 4343/9044 [16:15<14:43,  5.32it/s]
# Iteration:  48% 4344/9044 [16:15<14:43,  5.32it/s]
# Iteration:  48% 4345/9044 [16:15<14:43,  5.32it/s]
# Iteration:  48% 4346/9044 [16:15<14:42,  5.32it/s]
# ...

# %%
# !nvidia-smi
# Out:
# Fri Apr  7 16:02:51 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-SXM...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   30C    P0    45W / 400W |      0MiB / 40960MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !scp -r /content/experiments/epochs_2 /content/drive/MyDrive/ml/recipes/backup_data
